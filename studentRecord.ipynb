# %% [markdown]
# <a href="https://colab.research.google.com/github/safnanazar04-cmyk/python-essential/blob/main/studentRecord.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a Python program to manage the marks of students.

student_mark=[{
    "Roll_no":1,
    "Name":"Aarcha",
    "python_mark":94,
    "datascience_mark":95,
    "maths_mark":96
},{
    "Roll_no":2,
    "Name":"Muhsina",
    "python_mark":93,
    "datascience_mark":96,
    "maths_mark":94
},{
    "Roll_no":3,
    "Name":"Safna",
    "Python_mark":94,
    "Datascience_mark":93,
    "Maths_mark":95
}
]

print("===== STUDENT MANAGEMENT =====")

print("1. Add Student")
print("2. Display All Students")
print("3. Search Student by roll no")
print("4. Find topper")
print("5. Display Students who Passed")
print("6. Count Students Failed")
print("7. Display Subject-wise Highest Marks")
print("8. Exit")

choice=int(input("Enter your choice: "))

if choice==1:
  Roll_no=int(input("Enter roll no: "))
  Name=input("Enter name: ")
  Python_mark=int(input("Enter python mark: "))
  Datascience_mark=int(input("Enter datascience mark: "))
  Maths_mark=int(input("Enter maths mark: "))
  student_mark.append({
      "Roll_no":"Roll_no",
      "Name":"Name",
      "Python_mark":"Python_mark",
      "Datascience_mark":"Datascience_mark",
      "Maths_mark":"Maths_mark"
  })
  print("Student added successfully")
  print(student_mark)
# Out:
# ===== STUDENT MANAGEMENT =====
# 1. Add Student
# 2. Display All Students
# 3. Search Student by roll no
# 4. Find topper
# 5. Display Students who Passed
# 6. Count Students Failed
# 7. Display Subject-wise Highest Marks
# 8. Exit
# Enter your choice: 2

# %%
# !git --version
# Out:
# git version 2.34.1
